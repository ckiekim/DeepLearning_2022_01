# %% [markdown]
# # Cifar-10 이미지 분류 v2
# - 데이터 부풀리기 적용

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()

# %%
# X data: 0~1 사이의 실수(float32)로 변환
X_train = X_train.astype('float32') / 255. 
X_test = X_test.astype(np.float32) / 255.

# %%
# y_data: one-hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([ 
    Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_path = 'best-cifar10-v2.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %% [markdown]
# - 데이터 부풀리기

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(
    X_train, Y_train, stratify=Y_train, test_size=0.2, random_state=seed
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center=False,   # set input mean to 0 over the dataset
    samplewise_center=False,    # set each sample mean to 0
    featurewise_std_normalization=False,    # divide inputs by std of dataset
    samplewise_std_normalization=False,     # divide each input by its std
    zca_whitening=False,    # apply ZCA whitening
    zca_epsilon=1e-06,      # epsilon for ZCA whitening
    rotation_range=0,       # randomly rotate images in the range (deg 0 to 180)
    width_shift_range=0.1,  # randomly shift images horizontally
    height_shift_range=0.1, # randomly shift images vertically
    shear_range=0.,         # set range for random shear
    zoom_range=0.1,         # set range for random zoom
    channel_shift_range=0., # set range for random channel shifts
    fill_mode='nearest',    # set mode for filling points outside the input boundaries
    cval=0.,                # value used for fill_mode = "constant"
    horizontal_flip=True,   # randomly flip images
    vertical_flip=False,    # randomly flip images
    rescale=None,           # set rescaling factor (applied before any other transformation)
    preprocessing_function=None,    # set function that will be applied on each input
    data_format=None,       # image data format, either "channels_first" or "channels_last"
    validation_split=0.0    # fraction of images reserved for validation
)
datagen.fit(X_train)

# %%
hist = model.fit(
    datagen.flow(X_train, Y_train, batch_size=32),
    validation_data=(X_valid, Y_valid),
    epochs=100, verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.66868, saving model to best-cifar10-v2.h5
# 1250/1250 - 31s - loss: 1.8842 - accuracy: 0.3015 - val_loss: 1.6687 - val_accuracy: 0.4009 - 31s/epoch - 25ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.66868 to 1.42990, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.6118 - accuracy: 0.4058 - val_loss: 1.4299 - val_accuracy: 0.4812 - 20s/epoch - 16ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss did not improve from 1.42990
# 1250/1250 - 21s - loss: 1.5038 - accuracy: 0.4511 - val_loss: 1.4790 - val_accuracy: 0.4708 - 21s/epoch - 17ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.42990 to 1.26890, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.4301 - accuracy: 0.4864 - val_loss: 1.2689 - val_accuracy: 0.5503 - 20s/epoch - 16ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss did not improve from 1.26890
# 1250/1250 - 21s - loss: 1.3601 - accuracy: 0.5115 - val_loss: 1.2813 - val_accuracy: 0.5463 - 21s/epoch - 16ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.26890 to 1.14868, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.3074 - accuracy: 0.5346 - val_loss: 1.1487 - val_accuracy: 0.5923 - 21s/epoch - 16ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss did not improve from 1.14868
# 1250/1250 - 20s - loss: 1.2579 - accuracy: 0.5535 - val_loss: 1.2581 - val_accuracy: 0.5588 - 20s/epoch - 16ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 1.14868 to 1.02970, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.2152 - accuracy: 0.5696 - val_loss: 1.0297 - val_accuracy: 0.6344 - 21s/epoch - 16ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 1.02970
# 1250/1250 - 21s - loss: 1.1821 - accuracy: 0.5809 - val_loss: 1.1038 - val_accuracy: 0.6135 - 21s/epoch - 16ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 1.02970
# 1250/1250 - 21s - loss: 1.1495 - accuracy: 0.5939 - val_loss: 1.0491 - val_accuracy: 0.6322 - 21s/epoch - 17ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 1.02970
# 1250/1250 - 21s - loss: 1.1260 - accuracy: 0.6056 - val_loss: 1.0326 - val_accuracy: 0.6335 - 21s/epoch - 16ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 1.02970 to 0.97614, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.1020 - accuracy: 0.6095 - val_loss: 0.9761 - val_accuracy: 0.6565 - 21s/epoch - 16ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.97614 to 0.93524, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.0725 - accuracy: 0.6220 - val_loss: 0.9352 - val_accuracy: 0.6716 - 21s/epoch - 17ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.93524
# 1250/1250 - 20s - loss: 1.0571 - accuracy: 0.6273 - val_loss: 0.9779 - val_accuracy: 0.6625 - 20s/epoch - 16ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 0.93524
# 1250/1250 - 20s - loss: 1.0346 - accuracy: 0.6368 - val_loss: 0.9856 - val_accuracy: 0.6531 - 20s/epoch - 16ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss did not improve from 0.93524
# 1250/1250 - 20s - loss: 1.0243 - accuracy: 0.6396 - val_loss: 0.9417 - val_accuracy: 0.6653 - 20s/epoch - 16ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.93524 to 0.92035, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.0028 - accuracy: 0.6457 - val_loss: 0.9203 - val_accuracy: 0.6760 - 20s/epoch - 16ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.92035 to 0.88953, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.9874 - accuracy: 0.6524 - val_loss: 0.8895 - val_accuracy: 0.6945 - 20s/epoch - 16ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.88953
# 1250/1250 - 20s - loss: 0.9739 - accuracy: 0.6575 - val_loss: 0.8943 - val_accuracy: 0.6860 - 20s/epoch - 16ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.88953 to 0.84673, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.9678 - accuracy: 0.6634 - val_loss: 0.8467 - val_accuracy: 0.7056 - 20s/epoch - 16ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 0.84673
# 1250/1250 - 20s - loss: 0.9551 - accuracy: 0.6687 - val_loss: 0.9753 - val_accuracy: 0.6662 - 20s/epoch - 16ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.84673
# 1250/1250 - 21s - loss: 0.9408 - accuracy: 0.6708 - val_loss: 0.8772 - val_accuracy: 0.6974 - 21s/epoch - 17ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.84673 to 0.79149, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.9360 - accuracy: 0.6740 - val_loss: 0.7915 - val_accuracy: 0.7298 - 20s/epoch - 16ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.79149
# 1250/1250 - 21s - loss: 0.9290 - accuracy: 0.6795 - val_loss: 0.8140 - val_accuracy: 0.7172 - 21s/epoch - 16ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.79149 to 0.78430, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.9213 - accuracy: 0.6811 - val_loss: 0.7843 - val_accuracy: 0.7290 - 21s/epoch - 16ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 0.78430
# 1250/1250 - 20s - loss: 0.9160 - accuracy: 0.6825 - val_loss: 0.8235 - val_accuracy: 0.7107 - 20s/epoch - 16ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.78430
# 1250/1250 - 20s - loss: 0.9038 - accuracy: 0.6875 - val_loss: 0.8148 - val_accuracy: 0.7174 - 20s/epoch - 16ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.78430
# 1250/1250 - 21s - loss: 0.8983 - accuracy: 0.6896 - val_loss: 0.8062 - val_accuracy: 0.7231 - 21s/epoch - 17ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.78430
# 1250/1250 - 20s - loss: 0.8937 - accuracy: 0.6880 - val_loss: 0.8772 - val_accuracy: 0.7018 - 20s/epoch - 16ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 0.78430 to 0.76901, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.8855 - accuracy: 0.6947 - val_loss: 0.7690 - val_accuracy: 0.7368 - 21s/epoch - 16ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.76901
# 1250/1250 - 20s - loss: 0.8851 - accuracy: 0.6967 - val_loss: 0.8134 - val_accuracy: 0.7217 - 20s/epoch - 16ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss improved from 0.76901 to 0.76314, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.8735 - accuracy: 0.6984 - val_loss: 0.7631 - val_accuracy: 0.7421 - 21s/epoch - 16ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.76314
# 1250/1250 - 20s - loss: 0.8705 - accuracy: 0.7006 - val_loss: 0.7962 - val_accuracy: 0.7241 - 20s/epoch - 16ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss improved from 0.76314 to 0.76155, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.8696 - accuracy: 0.7010 - val_loss: 0.7616 - val_accuracy: 0.7397 - 21s/epoch - 17ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.76155
# 1250/1250 - 20s - loss: 0.8660 - accuracy: 0.7033 - val_loss: 0.7758 - val_accuracy: 0.7367 - 20s/epoch - 16ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss improved from 0.76155 to 0.73797, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.8580 - accuracy: 0.7035 - val_loss: 0.7380 - val_accuracy: 0.7509 - 21s/epoch - 17ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.73797
# 1250/1250 - 20s - loss: 0.8533 - accuracy: 0.7060 - val_loss: 0.7439 - val_accuracy: 0.7469 - 20s/epoch - 16ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.73797
# 1250/1250 - 20s - loss: 0.8519 - accuracy: 0.7081 - val_loss: 0.7576 - val_accuracy: 0.7402 - 20s/epoch - 16ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss improved from 0.73797 to 0.70619, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.8568 - accuracy: 0.7046 - val_loss: 0.7062 - val_accuracy: 0.7621 - 21s/epoch - 16ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.70619
# 1250/1250 - 21s - loss: 0.8467 - accuracy: 0.7087 - val_loss: 0.8188 - val_accuracy: 0.7312 - 21s/epoch - 16ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.70619
# 1250/1250 - 20s - loss: 0.8390 - accuracy: 0.7114 - val_loss: 0.7109 - val_accuracy: 0.7620 - 20s/epoch - 16ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.70619
# 1250/1250 - 21s - loss: 0.8496 - accuracy: 0.7095 - val_loss: 0.7358 - val_accuracy: 0.7495 - 21s/epoch - 16ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 0.70619
# 1250/1250 - 20s - loss: 0.8390 - accuracy: 0.7114 - val_loss: 0.7254 - val_accuracy: 0.7586 - 20s/epoch - 16ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.70619
# 1250/1250 - 21s - loss: 0.8460 - accuracy: 0.7114 - val_loss: 0.7419 - val_accuracy: 0.7485 - 21s/epoch - 16ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.70619
# 1250/1250 - 21s - loss: 0.8391 - accuracy: 0.7138 - val_loss: 0.7175 - val_accuracy: 0.7567 - 21s/epoch - 16ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.70619
# 1250/1250 - 21s - loss: 0.8370 - accuracy: 0.7125 - val_loss: 0.7534 - val_accuracy: 0.7489 - 21s/epoch - 17ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 0.70619
# 1250/1250 - 20s - loss: 0.8306 - accuracy: 0.7153 - val_loss: 0.7155 - val_accuracy: 0.7617 - 20s/epoch - 16ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss improved from 0.70619 to 0.70365, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.8269 - accuracy: 0.7158 - val_loss: 0.7037 - val_accuracy: 0.7635 - 21s/epoch - 17ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.70365
# 1250/1250 - 20s - loss: 0.8304 - accuracy: 0.7200 - val_loss: 0.7778 - val_accuracy: 0.7413 - 20s/epoch - 16ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.70365
# 1250/1250 - 20s - loss: 0.8175 - accuracy: 0.7219 - val_loss: 0.7143 - val_accuracy: 0.7608 - 20s/epoch - 16ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 0.70365
# 1250/1250 - 21s - loss: 0.8181 - accuracy: 0.7219 - val_loss: 0.7517 - val_accuracy: 0.7488 - 21s/epoch - 16ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.70365
# 1250/1250 - 21s - loss: 0.8250 - accuracy: 0.7217 - val_loss: 0.7445 - val_accuracy: 0.7491 - 21s/epoch - 16ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.70365
# 1250/1250 - 20s - loss: 0.8152 - accuracy: 0.7230 - val_loss: 0.7068 - val_accuracy: 0.7670 - 20s/epoch - 16ms/step
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.70365
# 1250/1250 - 20s - loss: 0.8129 - accuracy: 0.7218 - val_loss: 0.7206 - val_accuracy: 0.7618 - 20s/epoch - 16ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss improved from 0.70365 to 0.68903, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.8140 - accuracy: 0.7243 - val_loss: 0.6890 - val_accuracy: 0.7657 - 21s/epoch - 16ms/step
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.68903
# 1250/1250 - 21s - loss: 0.8184 - accuracy: 0.7238 - val_loss: 0.7087 - val_accuracy: 0.7655 - 21s/epoch - 17ms/step
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.68903
# 1250/1250 - 20s - loss: 0.8091 - accuracy: 0.7254 - val_loss: 0.7736 - val_accuracy: 0.7351 - 20s/epoch - 16ms/step
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.68903
# 1250/1250 - 21s - loss: 0.8137 - accuracy: 0.7230 - val_loss: 0.7809 - val_accuracy: 0.7448 - 21s/epoch - 16ms/step
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.68903
# 1250/1250 - 20s - loss: 0.8096 - accuracy: 0.7269 - val_loss: 0.7601 - val_accuracy: 0.7464 - 20s/epoch - 16ms/step
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.68903
# 1250/1250 - 21s - loss: 0.8080 - accuracy: 0.7264 - val_loss: 0.7029 - val_accuracy: 0.7754 - 21s/epoch - 16ms/step
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.68903
# 1250/1250 - 20s - loss: 0.8091 - accuracy: 0.7239 - val_loss: 0.6906 - val_accuracy: 0.7727 - 20s/epoch - 16ms/step
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.68903
# 1250/1250 - 21s - loss: 0.8022 - accuracy: 0.7277 - val_loss: 0.7521 - val_accuracy: 0.7505 - 21s/epoch - 16ms/step
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 0.68903
# 1250/1250 - 21s - loss: 0.8085 - accuracy: 0.7251 - val_loss: 0.7112 - val_accuracy: 0.7669 - 21s/epoch - 16ms/step
# Epoch 64/100
#
# Epoch 00064: val_loss improved from 0.68903 to 0.66986, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.8034 - accuracy: 0.7288 - val_loss: 0.6699 - val_accuracy: 0.7793 - 21s/epoch - 16ms/step
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.66986
# 1250/1250 - 20s - loss: 0.8049 - accuracy: 0.7252 - val_loss: 0.7508 - val_accuracy: 0.7558 - 20s/epoch - 16ms/step
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.66986
# 1250/1250 - 20s - loss: 0.7977 - accuracy: 0.7306 - val_loss: 0.8243 - val_accuracy: 0.7255 - 20s/epoch - 16ms/step
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.66986
# 1250/1250 - 20s - loss: 0.7994 - accuracy: 0.7311 - val_loss: 0.7197 - val_accuracy: 0.7655 - 20s/epoch - 16ms/step
# Epoch 68/100
#
# Epoch 00068: val_loss improved from 0.66986 to 0.64722, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.7964 - accuracy: 0.7308 - val_loss: 0.6472 - val_accuracy: 0.7890 - 21s/epoch - 16ms/step
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 0.64722
# 1250/1250 - 20s - loss: 0.8085 - accuracy: 0.7267 - val_loss: 0.7053 - val_accuracy: 0.7661 - 20s/epoch - 16ms/step
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 0.64722
# 1250/1250 - 20s - loss: 0.7971 - accuracy: 0.7298 - val_loss: 0.7869 - val_accuracy: 0.7337 - 20s/epoch - 16ms/step
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 0.64722
# 1250/1250 - 20s - loss: 0.7970 - accuracy: 0.7301 - val_loss: 0.7198 - val_accuracy: 0.7668 - 20s/epoch - 16ms/step
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 0.64722
# 1250/1250 - 20s - loss: 0.8042 - accuracy: 0.7309 - val_loss: 0.6521 - val_accuracy: 0.7838 - 20s/epoch - 16ms/step
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 0.64722
# 1250/1250 - 20s - loss: 0.7984 - accuracy: 0.7317 - val_loss: 0.7423 - val_accuracy: 0.7512 - 20s/epoch - 16ms/step
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.64722
# 1250/1250 - 20s - loss: 0.7946 - accuracy: 0.7332 - val_loss: 0.6805 - val_accuracy: 0.7766 - 20s/epoch - 16ms/step
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 0.64722
# 1250/1250 - 20s - loss: 0.8023 - accuracy: 0.7310 - val_loss: 0.6876 - val_accuracy: 0.7720 - 20s/epoch - 16ms/step
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.64722
# 1250/1250 - 21s - loss: 0.8002 - accuracy: 0.7307 - val_loss: 0.6840 - val_accuracy: 0.7741 - 21s/epoch - 16ms/step
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.64722
# 1250/1250 - 20s - loss: 0.7965 - accuracy: 0.7321 - val_loss: 0.6935 - val_accuracy: 0.7741 - 20s/epoch - 16ms/step
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 0.64722
# 1250/1250 - 21s - loss: 0.7922 - accuracy: 0.7329 - val_loss: 0.7155 - val_accuracy: 0.7702 - 21s/epoch - 16ms/step

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6619 - accuracy: 0.7807
# [0.6619385480880737, 0.7807000279426575]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
