# %% [markdown]
# # Cifar-10 이미지 분류 v1

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# 170508288/170498071 [==============================] - 6s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()

# %%
# X data: 0~1 사이의 실수(float32)로 변환
X_train = X_train.astype('float32') / 255. 
X_test = X_test.astype(np.float32) / 255.

# %%
# y_data: one-hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([ 
    Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_path = 'best-cifar10-v1.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2,
    epochs=100, batch_size=32, verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.57239, saving model to best-cifar10-v1.h5
# 1250/1250 - 33s - loss: 1.8277 - accuracy: 0.3289 - val_loss: 1.5724 - val_accuracy: 0.4285 - 33s/epoch - 26ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.57239 to 1.37781, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 1.5206 - accuracy: 0.4439 - val_loss: 1.3778 - val_accuracy: 0.5056 - 21s/epoch - 17ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.37781 to 1.27139, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 1.3941 - accuracy: 0.4944 - val_loss: 1.2714 - val_accuracy: 0.5537 - 22s/epoch - 18ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.27139 to 1.23855, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 1.2972 - accuracy: 0.5350 - val_loss: 1.2386 - val_accuracy: 0.5549 - 22s/epoch - 18ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.23855 to 1.19234, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 1.2162 - accuracy: 0.5671 - val_loss: 1.1923 - val_accuracy: 0.5831 - 22s/epoch - 18ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.19234 to 1.05592, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 1.1545 - accuracy: 0.5913 - val_loss: 1.0559 - val_accuracy: 0.6328 - 21s/epoch - 17ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss did not improve from 1.05592
# 1250/1250 - 21s - loss: 1.0995 - accuracy: 0.6168 - val_loss: 1.0678 - val_accuracy: 0.6190 - 21s/epoch - 17ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 1.05592 to 0.98990, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 1.0542 - accuracy: 0.6308 - val_loss: 0.9899 - val_accuracy: 0.6526 - 21s/epoch - 17ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.98990 to 0.96447, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 1.0122 - accuracy: 0.6461 - val_loss: 0.9645 - val_accuracy: 0.6621 - 21s/epoch - 17ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 0.96447
# 1250/1250 - 21s - loss: 0.9772 - accuracy: 0.6574 - val_loss: 0.9748 - val_accuracy: 0.6567 - 21s/epoch - 17ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.96447 to 0.88124, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.9484 - accuracy: 0.6697 - val_loss: 0.8812 - val_accuracy: 0.6919 - 21s/epoch - 17ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.88124 to 0.87204, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.9201 - accuracy: 0.6780 - val_loss: 0.8720 - val_accuracy: 0.6945 - 21s/epoch - 17ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 0.87204
# 1250/1250 - 21s - loss: 0.8974 - accuracy: 0.6860 - val_loss: 0.8750 - val_accuracy: 0.6934 - 21s/epoch - 17ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.87204 to 0.82598, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.8723 - accuracy: 0.6970 - val_loss: 0.8260 - val_accuracy: 0.7098 - 21s/epoch - 17ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.82598 to 0.82251, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.8497 - accuracy: 0.7056 - val_loss: 0.8225 - val_accuracy: 0.7113 - 21s/epoch - 17ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.82251 to 0.81323, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.8346 - accuracy: 0.7117 - val_loss: 0.8132 - val_accuracy: 0.7214 - 22s/epoch - 18ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.81323 to 0.77774, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.8185 - accuracy: 0.7148 - val_loss: 0.7777 - val_accuracy: 0.7281 - 22s/epoch - 18ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.77774 to 0.77457, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7988 - accuracy: 0.7236 - val_loss: 0.7746 - val_accuracy: 0.7329 - 22s/epoch - 18ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 0.77457 to 0.77222, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7896 - accuracy: 0.7267 - val_loss: 0.7722 - val_accuracy: 0.7333 - 22s/epoch - 18ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.77222 to 0.75601, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7780 - accuracy: 0.7351 - val_loss: 0.7560 - val_accuracy: 0.7410 - 22s/epoch - 18ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.75601 to 0.75297, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7648 - accuracy: 0.7355 - val_loss: 0.7530 - val_accuracy: 0.7389 - 22s/epoch - 18ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.75297
# 1250/1250 - 21s - loss: 0.7573 - accuracy: 0.7386 - val_loss: 0.7563 - val_accuracy: 0.7422 - 21s/epoch - 17ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.75297 to 0.73297, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.7489 - accuracy: 0.7425 - val_loss: 0.7330 - val_accuracy: 0.7507 - 21s/epoch - 17ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss improved from 0.73297 to 0.71613, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.7330 - accuracy: 0.7480 - val_loss: 0.7161 - val_accuracy: 0.7551 - 21s/epoch - 17ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 0.71613
# 1250/1250 - 22s - loss: 0.7323 - accuracy: 0.7496 - val_loss: 0.7169 - val_accuracy: 0.7557 - 22s/epoch - 18ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.71613 to 0.71413, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.7221 - accuracy: 0.7542 - val_loss: 0.7141 - val_accuracy: 0.7582 - 21s/epoch - 17ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 0.71413 to 0.70875, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7195 - accuracy: 0.7548 - val_loss: 0.7087 - val_accuracy: 0.7602 - 22s/epoch - 18ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.70875
# 1250/1250 - 21s - loss: 0.7117 - accuracy: 0.7574 - val_loss: 0.7154 - val_accuracy: 0.7538 - 21s/epoch - 17ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss improved from 0.70875 to 0.69279, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.7081 - accuracy: 0.7606 - val_loss: 0.6928 - val_accuracy: 0.7643 - 21s/epoch - 17ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.69279
# 1250/1250 - 21s - loss: 0.7025 - accuracy: 0.7634 - val_loss: 0.6931 - val_accuracy: 0.7642 - 21s/epoch - 17ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.69279
# 1250/1250 - 21s - loss: 0.6964 - accuracy: 0.7616 - val_loss: 0.7001 - val_accuracy: 0.7635 - 21s/epoch - 17ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.69279
# 1250/1250 - 21s - loss: 0.6968 - accuracy: 0.7625 - val_loss: 0.7075 - val_accuracy: 0.7614 - 21s/epoch - 17ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss improved from 0.69279 to 0.68748, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.6851 - accuracy: 0.7670 - val_loss: 0.6875 - val_accuracy: 0.7667 - 21s/epoch - 17ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.68748
# 1250/1250 - 22s - loss: 0.6801 - accuracy: 0.7683 - val_loss: 0.6983 - val_accuracy: 0.7635 - 22s/epoch - 18ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.68748
# 1250/1250 - 21s - loss: 0.6764 - accuracy: 0.7697 - val_loss: 0.7138 - val_accuracy: 0.7591 - 21s/epoch - 17ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.68748
# 1250/1250 - 22s - loss: 0.6797 - accuracy: 0.7692 - val_loss: 0.7118 - val_accuracy: 0.7585 - 22s/epoch - 18ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss improved from 0.68748 to 0.68001, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.6738 - accuracy: 0.7730 - val_loss: 0.6800 - val_accuracy: 0.7661 - 21s/epoch - 17ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss improved from 0.68001 to 0.67619, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.6693 - accuracy: 0.7746 - val_loss: 0.6762 - val_accuracy: 0.7711 - 21s/epoch - 17ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.67619
# 1250/1250 - 21s - loss: 0.6626 - accuracy: 0.7774 - val_loss: 0.6795 - val_accuracy: 0.7687 - 21s/epoch - 17ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.67619
# 1250/1250 - 22s - loss: 0.6592 - accuracy: 0.7766 - val_loss: 0.6823 - val_accuracy: 0.7674 - 22s/epoch - 18ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.67619
# 1250/1250 - 21s - loss: 0.6552 - accuracy: 0.7785 - val_loss: 0.6912 - val_accuracy: 0.7654 - 21s/epoch - 17ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.67619
# 1250/1250 - 21s - loss: 0.6556 - accuracy: 0.7790 - val_loss: 0.6793 - val_accuracy: 0.7726 - 21s/epoch - 17ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 0.67619 to 0.65296, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.6466 - accuracy: 0.7812 - val_loss: 0.6530 - val_accuracy: 0.7800 - 21s/epoch - 17ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.65296
# 1250/1250 - 21s - loss: 0.6501 - accuracy: 0.7824 - val_loss: 0.6826 - val_accuracy: 0.7732 - 21s/epoch - 17ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.65296
# 1250/1250 - 22s - loss: 0.6476 - accuracy: 0.7828 - val_loss: 0.6897 - val_accuracy: 0.7756 - 22s/epoch - 18ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.65296
# 1250/1250 - 21s - loss: 0.6436 - accuracy: 0.7821 - val_loss: 0.6736 - val_accuracy: 0.7766 - 21s/epoch - 17ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 0.65296
# 1250/1250 - 21s - loss: 0.6427 - accuracy: 0.7835 - val_loss: 0.6579 - val_accuracy: 0.7812 - 21s/epoch - 17ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.65296
# 1250/1250 - 21s - loss: 0.6340 - accuracy: 0.7855 - val_loss: 0.6597 - val_accuracy: 0.7815 - 21s/epoch - 17ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.65296
# 1250/1250 - 22s - loss: 0.6318 - accuracy: 0.7898 - val_loss: 0.6546 - val_accuracy: 0.7791 - 22s/epoch - 18ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.65296
# 1250/1250 - 21s - loss: 0.6275 - accuracy: 0.7890 - val_loss: 0.6653 - val_accuracy: 0.7779 - 21s/epoch - 17ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss improved from 0.65296 to 0.64684, saving model to best-cifar10-v1.h5
# 1250/1250 - 21s - loss: 0.6285 - accuracy: 0.7877 - val_loss: 0.6468 - val_accuracy: 0.7793 - 21s/epoch - 17ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.64684
# 1250/1250 - 22s - loss: 0.6326 - accuracy: 0.7875 - val_loss: 0.6653 - val_accuracy: 0.7702 - 22s/epoch - 18ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.64684
# 1250/1250 - 21s - loss: 0.6216 - accuracy: 0.7915 - val_loss: 0.6533 - val_accuracy: 0.7791 - 21s/epoch - 17ms/step
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.64684
# 1250/1250 - 22s - loss: 0.6267 - accuracy: 0.7904 - val_loss: 0.6522 - val_accuracy: 0.7825 - 22s/epoch - 18ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.64684
# 1250/1250 - 21s - loss: 0.6186 - accuracy: 0.7939 - val_loss: 0.6800 - val_accuracy: 0.7796 - 21s/epoch - 17ms/step
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.64684
# 1250/1250 - 22s - loss: 0.6198 - accuracy: 0.7936 - val_loss: 0.6614 - val_accuracy: 0.7797 - 22s/epoch - 18ms/step
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.64684
# 1250/1250 - 21s - loss: 0.6178 - accuracy: 0.7939 - val_loss: 0.6839 - val_accuracy: 0.7759 - 21s/epoch - 17ms/step
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.64684
# 1250/1250 - 22s - loss: 0.6146 - accuracy: 0.7959 - val_loss: 0.6760 - val_accuracy: 0.7781 - 22s/epoch - 18ms/step
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.64684
# 1250/1250 - 22s - loss: 0.6110 - accuracy: 0.7947 - val_loss: 0.6604 - val_accuracy: 0.7798 - 22s/epoch - 18ms/step
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.64684
# 1250/1250 - 21s - loss: 0.6116 - accuracy: 0.7942 - val_loss: 0.7022 - val_accuracy: 0.7716 - 21s/epoch - 17ms/step
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.64684
# 1250/1250 - 21s - loss: 0.6121 - accuracy: 0.7965 - val_loss: 0.6602 - val_accuracy: 0.7828 - 21s/epoch - 17ms/step

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6675 - accuracy: 0.7818
# [0.6675269603729248, 0.7817999720573425]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
