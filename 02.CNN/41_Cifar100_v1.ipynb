# %% [markdown]
# # Cifar-100 이미지 분류 v1
# - Cifar-10과 동일한 모델

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar100
(X_train, y_train), (X_test, y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 3s 0us/step
# 169017344/169001437 [==============================] - 3s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1))

# %%
class_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'    
]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
for i in range(40):
    plt.subplot(4,10,i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()

# %%
# X data: 0~1 사이의 실수(float32)로 변환
# X_train = X_train.astype(float) / 255. , X_train = X_train / 255. ==> 64bit 실수
X_train = X_train.astype('float32') / 255. 
X_test = X_test.astype(np.float32) / 255.

# %%
# y_data: one-hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([ 
    Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(100, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 100)               51300
#
# =================================================================
# Total params: 1,297,028
# Trainable params: 1,297,028
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_path = 'best-cifar100-v1.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2,
    epochs=100, batch_size=32, verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 4.08393, saving model to best-cifar100-v1.h5
# 1250/1250 - 17s - loss: 4.3626 - accuracy: 0.0389 - val_loss: 4.0839 - val_accuracy: 0.0881 - 17s/epoch - 14ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 4.08393 to 3.69303, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 3.9542 - accuracy: 0.0965 - val_loss: 3.6930 - val_accuracy: 0.1464 - 6s/epoch - 5ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 3.69303 to 3.49589, saving model to best-cifar100-v1.h5
# 1250/1250 - 7s - loss: 3.6940 - accuracy: 0.1367 - val_loss: 3.4959 - val_accuracy: 0.1838 - 7s/epoch - 5ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 3.49589 to 3.36526, saving model to best-cifar100-v1.h5
# 1250/1250 - 7s - loss: 3.5143 - accuracy: 0.1667 - val_loss: 3.3653 - val_accuracy: 0.2042 - 7s/epoch - 5ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 3.36526 to 3.22443, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 3.3765 - accuracy: 0.1932 - val_loss: 3.2244 - val_accuracy: 0.2291 - 6s/epoch - 5ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 3.22443 to 3.09745, saving model to best-cifar100-v1.h5
# 1250/1250 - 7s - loss: 3.2605 - accuracy: 0.2137 - val_loss: 3.0974 - val_accuracy: 0.2546 - 7s/epoch - 5ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 3.09745 to 3.03240, saving model to best-cifar100-v1.h5
# 1250/1250 - 7s - loss: 3.1559 - accuracy: 0.2337 - val_loss: 3.0324 - val_accuracy: 0.2602 - 7s/epoch - 5ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 3.03240 to 2.93155, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 3.0751 - accuracy: 0.2482 - val_loss: 2.9315 - val_accuracy: 0.2801 - 6s/epoch - 5ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 2.93155 to 2.89488, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.9958 - accuracy: 0.2629 - val_loss: 2.8949 - val_accuracy: 0.2879 - 6s/epoch - 5ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 2.89488 to 2.81376, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.9304 - accuracy: 0.2723 - val_loss: 2.8138 - val_accuracy: 0.3056 - 6s/epoch - 5ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 2.81376 to 2.75506, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.8739 - accuracy: 0.2883 - val_loss: 2.7551 - val_accuracy: 0.3203 - 6s/epoch - 5ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 2.75506 to 2.73417, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.8178 - accuracy: 0.2993 - val_loss: 2.7342 - val_accuracy: 0.3222 - 6s/epoch - 5ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 2.73417
# 1250/1250 - 6s - loss: 2.7720 - accuracy: 0.3075 - val_loss: 2.7373 - val_accuracy: 0.3229 - 6s/epoch - 5ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 2.73417 to 2.69476, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.7262 - accuracy: 0.3155 - val_loss: 2.6948 - val_accuracy: 0.3316 - 6s/epoch - 5ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 2.69476 to 2.59258, saving model to best-cifar100-v1.h5
# 1250/1250 - 7s - loss: 2.6818 - accuracy: 0.3266 - val_loss: 2.5926 - val_accuracy: 0.3540 - 7s/epoch - 5ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 2.59258 to 2.58660, saving model to best-cifar100-v1.h5
# 1250/1250 - 7s - loss: 2.6391 - accuracy: 0.3336 - val_loss: 2.5866 - val_accuracy: 0.3572 - 7s/epoch - 5ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 2.58660 to 2.54922, saving model to best-cifar100-v1.h5
# 1250/1250 - 7s - loss: 2.6036 - accuracy: 0.3440 - val_loss: 2.5492 - val_accuracy: 0.3598 - 7s/epoch - 5ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 2.54922 to 2.53917, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.5633 - accuracy: 0.3507 - val_loss: 2.5392 - val_accuracy: 0.3642 - 6s/epoch - 5ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 2.53917 to 2.48968, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.5409 - accuracy: 0.3541 - val_loss: 2.4897 - val_accuracy: 0.3705 - 6s/epoch - 5ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 2.48968 to 2.47220, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.5067 - accuracy: 0.3652 - val_loss: 2.4722 - val_accuracy: 0.3769 - 6s/epoch - 5ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 2.47220 to 2.44272, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.4831 - accuracy: 0.3707 - val_loss: 2.4427 - val_accuracy: 0.3800 - 6s/epoch - 5ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 2.44272
# 1250/1250 - 7s - loss: 2.4565 - accuracy: 0.3740 - val_loss: 2.4444 - val_accuracy: 0.3818 - 7s/epoch - 5ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 2.44272 to 2.39802, saving model to best-cifar100-v1.h5
# 1250/1250 - 7s - loss: 2.4278 - accuracy: 0.3822 - val_loss: 2.3980 - val_accuracy: 0.3877 - 7s/epoch - 5ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 2.39802
# 1250/1250 - 6s - loss: 2.4117 - accuracy: 0.3843 - val_loss: 2.4280 - val_accuracy: 0.3888 - 6s/epoch - 5ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 2.39802 to 2.38686, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.4005 - accuracy: 0.3867 - val_loss: 2.3869 - val_accuracy: 0.3924 - 6s/epoch - 5ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 2.38686 to 2.38076, saving model to best-cifar100-v1.h5
# 1250/1250 - 7s - loss: 2.3709 - accuracy: 0.3893 - val_loss: 2.3808 - val_accuracy: 0.3967 - 7s/epoch - 5ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 2.38076 to 2.36435, saving model to best-cifar100-v1.h5
# 1250/1250 - 7s - loss: 2.3616 - accuracy: 0.3939 - val_loss: 2.3644 - val_accuracy: 0.4020 - 7s/epoch - 5ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 2.36435 to 2.33330, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.3412 - accuracy: 0.3990 - val_loss: 2.3333 - val_accuracy: 0.4080 - 6s/epoch - 5ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 2.33330
# 1250/1250 - 6s - loss: 2.3286 - accuracy: 0.4026 - val_loss: 2.3621 - val_accuracy: 0.4026 - 6s/epoch - 5ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 2.33330 to 2.33225, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.3162 - accuracy: 0.4057 - val_loss: 2.3322 - val_accuracy: 0.4086 - 6s/epoch - 5ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 2.33225
# 1250/1250 - 7s - loss: 2.3039 - accuracy: 0.4087 - val_loss: 2.3391 - val_accuracy: 0.4084 - 7s/epoch - 5ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss improved from 2.33225 to 2.31127, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.2977 - accuracy: 0.4095 - val_loss: 2.3113 - val_accuracy: 0.4137 - 6s/epoch - 5ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss improved from 2.31127 to 2.29612, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.2880 - accuracy: 0.4130 - val_loss: 2.2961 - val_accuracy: 0.4189 - 6s/epoch - 5ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss improved from 2.29612 to 2.29490, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.2659 - accuracy: 0.4195 - val_loss: 2.2949 - val_accuracy: 0.4151 - 6s/epoch - 5ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss improved from 2.29490 to 2.26242, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.2601 - accuracy: 0.4180 - val_loss: 2.2624 - val_accuracy: 0.4269 - 6s/epoch - 5ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss improved from 2.26242 to 2.25765, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.2591 - accuracy: 0.4220 - val_loss: 2.2576 - val_accuracy: 0.4285 - 6s/epoch - 5ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss improved from 2.25765 to 2.24709, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.2473 - accuracy: 0.4240 - val_loss: 2.2471 - val_accuracy: 0.4274 - 6s/epoch - 5ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 2.24709
# 1250/1250 - 7s - loss: 2.2348 - accuracy: 0.4279 - val_loss: 2.2521 - val_accuracy: 0.4294 - 7s/epoch - 5ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss improved from 2.24709 to 2.24630, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.2359 - accuracy: 0.4241 - val_loss: 2.2463 - val_accuracy: 0.4296 - 6s/epoch - 5ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 2.24630
# 1250/1250 - 6s - loss: 2.2230 - accuracy: 0.4292 - val_loss: 2.2565 - val_accuracy: 0.4288 - 6s/epoch - 5ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss improved from 2.24630 to 2.23952, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.2150 - accuracy: 0.4324 - val_loss: 2.2395 - val_accuracy: 0.4325 - 6s/epoch - 5ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss improved from 2.23952 to 2.23442, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.2063 - accuracy: 0.4346 - val_loss: 2.2344 - val_accuracy: 0.4346 - 6s/epoch - 5ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 2.23442 to 2.21182, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.2018 - accuracy: 0.4344 - val_loss: 2.2118 - val_accuracy: 0.4381 - 6s/epoch - 5ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss improved from 2.21182 to 2.19730, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.2111 - accuracy: 0.4336 - val_loss: 2.1973 - val_accuracy: 0.4378 - 6s/epoch - 5ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 2.19730
# 1250/1250 - 6s - loss: 2.1915 - accuracy: 0.4367 - val_loss: 2.2123 - val_accuracy: 0.4354 - 6s/epoch - 5ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 2.19730
# 1250/1250 - 6s - loss: 2.1923 - accuracy: 0.4339 - val_loss: 2.2424 - val_accuracy: 0.4330 - 6s/epoch - 5ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 2.19730
# 1250/1250 - 6s - loss: 2.1828 - accuracy: 0.4360 - val_loss: 2.2918 - val_accuracy: 0.4317 - 6s/epoch - 5ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss improved from 2.19730 to 2.19087, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.1919 - accuracy: 0.4386 - val_loss: 2.1909 - val_accuracy: 0.4442 - 6s/epoch - 5ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 2.19087
# 1250/1250 - 6s - loss: 2.1813 - accuracy: 0.4393 - val_loss: 2.2474 - val_accuracy: 0.4314 - 6s/epoch - 5ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 2.19087
# 1250/1250 - 6s - loss: 2.1741 - accuracy: 0.4412 - val_loss: 2.1933 - val_accuracy: 0.4413 - 6s/epoch - 5ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 2.19087
# 1250/1250 - 6s - loss: 2.1712 - accuracy: 0.4428 - val_loss: 2.1925 - val_accuracy: 0.4426 - 6s/epoch - 5ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 2.19087
# 1250/1250 - 6s - loss: 2.1700 - accuracy: 0.4437 - val_loss: 2.2162 - val_accuracy: 0.4475 - 6s/epoch - 5ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 2.19087
# 1250/1250 - 6s - loss: 2.1645 - accuracy: 0.4490 - val_loss: 2.2431 - val_accuracy: 0.4382 - 6s/epoch - 5ms/step
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 2.19087
# 1250/1250 - 6s - loss: 2.1723 - accuracy: 0.4439 - val_loss: 2.2018 - val_accuracy: 0.4425 - 6s/epoch - 5ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss improved from 2.19087 to 2.18131, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.1664 - accuracy: 0.4457 - val_loss: 2.1813 - val_accuracy: 0.4429 - 6s/epoch - 5ms/step
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 2.18131
# 1250/1250 - 6s - loss: 2.1604 - accuracy: 0.4481 - val_loss: 2.2605 - val_accuracy: 0.4468 - 6s/epoch - 5ms/step
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 2.18131
# 1250/1250 - 6s - loss: 2.1530 - accuracy: 0.4502 - val_loss: 2.2203 - val_accuracy: 0.4375 - 6s/epoch - 5ms/step
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 2.18131
# 1250/1250 - 7s - loss: 2.1513 - accuracy: 0.4494 - val_loss: 2.2392 - val_accuracy: 0.4440 - 7s/epoch - 5ms/step
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 2.18131
# 1250/1250 - 6s - loss: 2.1495 - accuracy: 0.4453 - val_loss: 2.1983 - val_accuracy: 0.4468 - 6s/epoch - 5ms/step
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 2.18131
# 1250/1250 - 6s - loss: 2.1488 - accuracy: 0.4488 - val_loss: 2.1883 - val_accuracy: 0.4427 - 6s/epoch - 5ms/step
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 2.18131
# 1250/1250 - 6s - loss: 2.1430 - accuracy: 0.4480 - val_loss: 2.2027 - val_accuracy: 0.4448 - 6s/epoch - 5ms/step
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 2.18131
# 1250/1250 - 6s - loss: 2.1428 - accuracy: 0.4516 - val_loss: 2.1895 - val_accuracy: 0.4495 - 6s/epoch - 5ms/step
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 2.18131
# 1250/1250 - 6s - loss: 2.1514 - accuracy: 0.4460 - val_loss: 2.2181 - val_accuracy: 0.4445 - 6s/epoch - 5ms/step
# Epoch 64/100
#
# Epoch 00064: val_loss improved from 2.18131 to 2.15620, saving model to best-cifar100-v1.h5
# 1250/1250 - 6s - loss: 2.1465 - accuracy: 0.4514 - val_loss: 2.1562 - val_accuracy: 0.4500 - 6s/epoch - 5ms/step
# Epoch 65/100
#
# Epoch 00065: val_loss improved from 2.15620 to 2.15010, saving model to best-cifar100-v1.h5
# 1250/1250 - 7s - loss: 2.1458 - accuracy: 0.4523 - val_loss: 2.1501 - val_accuracy: 0.4548 - 7s/epoch - 5ms/step
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 2.15010
# 1250/1250 - 6s - loss: 2.1374 - accuracy: 0.4525 - val_loss: 2.2372 - val_accuracy: 0.4405 - 6s/epoch - 5ms/step
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 2.15010
# 1250/1250 - 6s - loss: 2.1344 - accuracy: 0.4518 - val_loss: 2.2169 - val_accuracy: 0.4367 - 6s/epoch - 5ms/step
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 2.15010
# 1250/1250 - 6s - loss: 2.1464 - accuracy: 0.4494 - val_loss: 2.2841 - val_accuracy: 0.4470 - 6s/epoch - 5ms/step
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 2.15010
# 1250/1250 - 6s - loss: 2.1368 - accuracy: 0.4510 - val_loss: 2.1950 - val_accuracy: 0.4398 - 6s/epoch - 5ms/step
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 2.15010
# 1250/1250 - 6s - loss: 2.1416 - accuracy: 0.4503 - val_loss: 2.1648 - val_accuracy: 0.4484 - 6s/epoch - 5ms/step
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 2.15010
# 1250/1250 - 6s - loss: 2.1376 - accuracy: 0.4505 - val_loss: 2.1688 - val_accuracy: 0.4486 - 6s/epoch - 5ms/step
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 2.15010
# 1250/1250 - 6s - loss: 2.1361 - accuracy: 0.4525 - val_loss: 2.1746 - val_accuracy: 0.4469 - 6s/epoch - 5ms/step
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 2.15010
# 1250/1250 - 6s - loss: 2.1361 - accuracy: 0.4513 - val_loss: 2.1592 - val_accuracy: 0.4508 - 6s/epoch - 5ms/step
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 2.15010
# 1250/1250 - 7s - loss: 2.1348 - accuracy: 0.4507 - val_loss: 2.2109 - val_accuracy: 0.4524 - 7s/epoch - 5ms/step
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 2.15010
# 1250/1250 - 6s - loss: 2.1329 - accuracy: 0.4516 - val_loss: 2.2364 - val_accuracy: 0.4399 - 6s/epoch - 5ms/step

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 2.1169 - accuracy: 0.4508
# [2.11688232421875, 0.45080000162124634]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
