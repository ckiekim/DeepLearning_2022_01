# %% [markdown]
# # 고양이, 개 분류 - CNN v4
# - Dropout 추가
# - 이미지를 중앙에 배치
# - 각 이미지를 10개씩 부풀려 파일로 저장하고 이 파일로 학습

# %%
import cv2, os
import numpy as np
from tqdm.notebook import tqdm
from PIL import Image
import matplotlib.pyplot as plt

# %%
# !wget https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Out:
# --2022-01-23 08:20:12--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.153.128, 142.250.145.128, 173.194.79.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.153.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘cats_and_dogs_filtered.zip’
#
# cats_and_dogs_filte 100%[===================>]  65.43M  35.0MB/s    in 1.9s
#
# 2022-01-23 08:20:15 (35.0 MB/s) - ‘cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
# !unzip cats_and_dogs_filtered.zip > /dev/null

# %% [markdown]
# - 데이터 탐색

# %%
# 이미지를 축소/확대 및 센터링해서 이미지를 리턴하는 함수
IMAGE_SIZE = 150

def center_image(img, format='Image'):
    if format == 'Image':               # pillow image
        h, w, _ = np.array(img).shape
    else:                               # numpy array
        h, w = img.shape[:-1]
    if h > w:
        width, height = IMAGE_SIZE, (h * IMAGE_SIZE) // w
    else:
        width, height = (w * IMAGE_SIZE) // h, IMAGE_SIZE

    new_img = np.array(img.resize((width,height)))

    diff = abs(width - height)//2
    if width > height:
        final_img = new_img[:, diff:diff+IMAGE_SIZE, :]
    else:
        final_img = new_img[diff:diff+IMAGE_SIZE, :, :]

    return Image.fromarray(final_img) if format == 'Image' else final_img

# %%
CENTER_DIR = 'cats_and_dogs_centered'
train_dir = f'{CENTER_DIR}/train'
validation_dir = f'{CENTER_DIR}/validation'
train_cats_dir = f'{CENTER_DIR}/train/cats'
train_dogs_dir = f'{CENTER_DIR}/train/dogs'
validation_cats_dir = f'{CENTER_DIR}/validation/cats'
validation_dogs_dir = f'{CENTER_DIR}/validation/dogs'

# %%
if not os.path.exists(CENTER_DIR):
    os.mkdir(CENTER_DIR)
for dir in [train_dir,validation_dir,train_cats_dir,train_dogs_dir,validation_cats_dir,validation_dogs_dir]:
    os.mkdir(dir)

# %%
old_train_cats_dir = 'cats_and_dogs_filtered/train/cats'
old_train_dogs_dir = 'cats_and_dogs_filtered/train/dogs'
old_validation_cats_dir = 'cats_and_dogs_filtered/validation/cats'
old_validation_dogs_dir = 'cats_and_dogs_filtered/validation/dogs'

# %%
# cats_and_dogs_filtered -> image 축소/확대후 centering -> cats_and_dogs_centered
from glob import glob
for src_dir in [old_train_cats_dir,old_train_dogs_dir,old_validation_cats_dir,old_validation_dogs_dir]:
    dst_dir = src_dir.split('/')[1:]            # cats_and_dogs_filtered 제거
    dst_dir = '/'.join([CENTER_DIR] + dst_dir)  # CENTER_DIR 밑에 오는 디렉토리 지정
    for fname in glob(f'{src_dir}/*.jpg'):
        dst_fname = fname.split('/')[-1]    # 예를 들어, cat.475.jpg
        src_img = Image.open(fname)         # 사이즈가 제각각인 이미지
        dst_img = center_image(src_img)     # 150 x 150으로 centering된 이미지(pillow로 변경됨)
        dst_img.save(f'{dst_dir}/{dst_fname}')

# %% [markdown]
# - 이미지 부풀리기

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array, load_img

train_datagen = ImageDataGenerator(
    rescale=1/255.,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.5,
    zoom_range=[0.8, 1.2],
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
for fname in tqdm(glob(f'{train_cats_dir}/*.jpg')):
    img = load_img(fname)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    pre = fname.split('.')[1]
    count = 0
    for _ in train_datagen.flow(x, batch_size=1, save_to_dir=train_cats_dir, save_prefix=pre):
        count += 1
        if count >= 10:
            break
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
for fname in tqdm(glob(f'{train_dogs_dir}/*.jpg')):
    img = load_img(fname)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    pre = fname.split('.')[1]
    count = 0
    for _ in train_datagen.flow(x, batch_size=1, save_to_dir=train_dogs_dir, save_prefix=pre):
        count += 1
        if count >= 10:
            break
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
len(os.listdir(train_cats_dir)), len(os.listdir(train_dogs_dir))
# Out:
# (10994, 10998)

# %%
plt.figure(figsize=(12,5))
cat_fnames = glob(f'{train_cats_dir}/*')
dog_fnames = glob(f'{train_dogs_dir}/*')
for i in range(5):
    img = Image.open(cat_fnames[i])
    plt.subplot(2,5,i+1)
    plt.imshow(img), plt.title(cat_fnames[i].split('/')[-1]), plt.xticks([]), plt.yticks([])
    img = Image.open(dog_fnames[i])
    plt.subplot(2,5,i+1+5)
    plt.imshow(img), plt.title(dog_fnames[i].split('/')[-1]), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# - 모델 구성

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
model = Sequential([
    Conv2D(16, kernel_size=(3,3), input_shape=(150,150,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(32, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  dropout (Dropout)           (None, 74, 74, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 36, 36, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 17, 17, 64)        0
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - 모델 설정

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(
    optimizer=RMSprop(learning_rate=0.001, decay=1e-6),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# - 파일에서 이미지 데이터 읽어오는 방법

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
validation_generator = test_datagen.flow_from_directory(
    validation_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
# Out:
# Found 21992 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# - callback 정의

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

model_path = 'best-cat-dog-v4.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %% [markdown]
# - 모델 실행

# %%
hist = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=100,
    steps_per_epoch=100,        # 한번의 epoch에서 훈련에 사용할 batch의 갯수
    validation_steps=50,        # 한번의 epoch가 끝났을 때, 테스트에 사용되는 batch의 갯수
    verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.69205, saving model to best-cat-dog-v4.h5
# 100/100 - 15s - loss: 0.7487 - accuracy: 0.5205 - val_loss: 0.6921 - val_accuracy: 0.4970 - 15s/epoch - 152ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.69205 to 0.64202, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.6888 - accuracy: 0.5522 - val_loss: 0.6420 - val_accuracy: 0.6390 - 4s/epoch - 43ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.64202 to 0.63648, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.6581 - accuracy: 0.6400 - val_loss: 0.6365 - val_accuracy: 0.6280 - 4s/epoch - 42ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.63648 to 0.60320, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.6356 - accuracy: 0.6680 - val_loss: 0.6032 - val_accuracy: 0.6870 - 4s/epoch - 41ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss did not improve from 0.60320
# 100/100 - 4s - loss: 0.6035 - accuracy: 0.6745 - val_loss: 0.6431 - val_accuracy: 0.6490 - 4s/epoch - 40ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss did not improve from 0.60320
# 100/100 - 4s - loss: 0.5783 - accuracy: 0.7035 - val_loss: 0.6203 - val_accuracy: 0.6480 - 4s/epoch - 40ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.60320 to 0.56371, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.5879 - accuracy: 0.7085 - val_loss: 0.5637 - val_accuracy: 0.7130 - 4s/epoch - 43ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.56371 to 0.54280, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.5678 - accuracy: 0.7105 - val_loss: 0.5428 - val_accuracy: 0.7190 - 4s/epoch - 42ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 0.54280
# 100/100 - 4s - loss: 0.5506 - accuracy: 0.7285 - val_loss: 0.5685 - val_accuracy: 0.7180 - 4s/epoch - 40ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 0.54280
# 100/100 - 4s - loss: 0.5672 - accuracy: 0.7030 - val_loss: 0.5637 - val_accuracy: 0.7050 - 4s/epoch - 40ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 0.54280
# 100/100 - 4s - loss: 0.5655 - accuracy: 0.7220 - val_loss: 0.5592 - val_accuracy: 0.7100 - 4s/epoch - 41ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss did not improve from 0.54280
# 100/100 - 4s - loss: 0.5409 - accuracy: 0.7235 - val_loss: 0.5543 - val_accuracy: 0.7240 - 4s/epoch - 41ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.54280 to 0.54191, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.5423 - accuracy: 0.7340 - val_loss: 0.5419 - val_accuracy: 0.7220 - 4s/epoch - 42ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.54191
# 100/100 - 4s - loss: 0.5337 - accuracy: 0.7480 - val_loss: 0.5574 - val_accuracy: 0.7250 - 4s/epoch - 42ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 0.54191
# 100/100 - 4s - loss: 0.5279 - accuracy: 0.7490 - val_loss: 0.5972 - val_accuracy: 0.6880 - 4s/epoch - 42ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.54191 to 0.53886, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.5182 - accuracy: 0.7435 - val_loss: 0.5389 - val_accuracy: 0.7250 - 4s/epoch - 43ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 0.53886
# 100/100 - 4s - loss: 0.5284 - accuracy: 0.7375 - val_loss: 0.5518 - val_accuracy: 0.7280 - 4s/epoch - 41ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 0.53886
# 100/100 - 4s - loss: 0.5132 - accuracy: 0.7465 - val_loss: 0.5746 - val_accuracy: 0.7210 - 4s/epoch - 41ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 0.53886 to 0.51904, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.5083 - accuracy: 0.7510 - val_loss: 0.5190 - val_accuracy: 0.7330 - 4s/epoch - 42ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 0.51904
# 100/100 - 4s - loss: 0.4807 - accuracy: 0.7740 - val_loss: 0.5341 - val_accuracy: 0.7290 - 4s/epoch - 41ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.51904 to 0.50118, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.5010 - accuracy: 0.7520 - val_loss: 0.5012 - val_accuracy: 0.7460 - 4s/epoch - 43ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.50118
# 100/100 - 4s - loss: 0.4691 - accuracy: 0.7775 - val_loss: 0.5239 - val_accuracy: 0.7240 - 4s/epoch - 41ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 0.50118
# 100/100 - 4s - loss: 0.5033 - accuracy: 0.7630 - val_loss: 0.5343 - val_accuracy: 0.7330 - 4s/epoch - 40ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.50118
# 100/100 - 4s - loss: 0.4615 - accuracy: 0.7795 - val_loss: 0.5381 - val_accuracy: 0.7530 - 4s/epoch - 41ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 0.50118
# 100/100 - 4s - loss: 0.5007 - accuracy: 0.7715 - val_loss: 0.8092 - val_accuracy: 0.6340 - 4s/epoch - 41ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.50118 to 0.49950, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.4998 - accuracy: 0.7480 - val_loss: 0.4995 - val_accuracy: 0.7640 - 4s/epoch - 42ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.49950
# 100/100 - 4s - loss: 0.4889 - accuracy: 0.7760 - val_loss: 0.5855 - val_accuracy: 0.7380 - 4s/epoch - 40ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.49950
# 100/100 - 4s - loss: 0.5006 - accuracy: 0.7505 - val_loss: 0.5122 - val_accuracy: 0.7410 - 4s/epoch - 41ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.49950
# 100/100 - 4s - loss: 0.4849 - accuracy: 0.7765 - val_loss: 0.5989 - val_accuracy: 0.7100 - 4s/epoch - 41ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.49950
# 100/100 - 4s - loss: 0.4547 - accuracy: 0.7975 - val_loss: 0.5724 - val_accuracy: 0.7350 - 4s/epoch - 40ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.49950
# 100/100 - 4s - loss: 0.4544 - accuracy: 0.7885 - val_loss: 0.5255 - val_accuracy: 0.7400 - 4s/epoch - 41ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.49950
# 100/100 - 4s - loss: 0.4843 - accuracy: 0.7760 - val_loss: 0.5002 - val_accuracy: 0.7630 - 4s/epoch - 39ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.49950
# 100/100 - 4s - loss: 0.4722 - accuracy: 0.7810 - val_loss: 0.5242 - val_accuracy: 0.7660 - 4s/epoch - 39ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss improved from 0.49950 to 0.49337, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.4656 - accuracy: 0.7900 - val_loss: 0.4934 - val_accuracy: 0.7640 - 4s/epoch - 42ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.49337
# 100/100 - 4s - loss: 0.4666 - accuracy: 0.7805 - val_loss: 0.5815 - val_accuracy: 0.7400 - 4s/epoch - 41ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.49337
# 100/100 - 4s - loss: 0.4710 - accuracy: 0.7840 - val_loss: 0.5133 - val_accuracy: 0.7620 - 4s/epoch - 40ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.49337
# 100/100 - 4s - loss: 0.4407 - accuracy: 0.8050 - val_loss: 0.5096 - val_accuracy: 0.7650 - 4s/epoch - 40ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.49337
# 100/100 - 4s - loss: 0.4361 - accuracy: 0.8105 - val_loss: 0.5023 - val_accuracy: 0.7700 - 4s/epoch - 41ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss improved from 0.49337 to 0.48441, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.4326 - accuracy: 0.7975 - val_loss: 0.4844 - val_accuracy: 0.7640 - 4s/epoch - 42ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.48441
# 100/100 - 4s - loss: 0.4435 - accuracy: 0.7950 - val_loss: 0.5004 - val_accuracy: 0.7600 - 4s/epoch - 40ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss improved from 0.48441 to 0.45970, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.4398 - accuracy: 0.7960 - val_loss: 0.4597 - val_accuracy: 0.7870 - 4s/epoch - 41ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.45970
# 100/100 - 4s - loss: 0.4453 - accuracy: 0.8075 - val_loss: 0.5338 - val_accuracy: 0.7470 - 4s/epoch - 40ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 0.45970 to 0.45923, saving model to best-cat-dog-v4.h5
# 100/100 - 4s - loss: 0.4604 - accuracy: 0.7905 - val_loss: 0.4592 - val_accuracy: 0.7900 - 4s/epoch - 42ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.45923
# 100/100 - 4s - loss: 0.4362 - accuracy: 0.8035 - val_loss: 0.4974 - val_accuracy: 0.7750 - 4s/epoch - 40ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.45923
# 100/100 - 4s - loss: 0.4237 - accuracy: 0.8000 - val_loss: 0.4760 - val_accuracy: 0.7900 - 4s/epoch - 40ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.45923
# 100/100 - 4s - loss: 0.4492 - accuracy: 0.7910 - val_loss: 0.5505 - val_accuracy: 0.7360 - 4s/epoch - 40ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 0.45923
# 100/100 - 4s - loss: 0.4295 - accuracy: 0.8150 - val_loss: 0.4999 - val_accuracy: 0.7650 - 4s/epoch - 40ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.45923
# 100/100 - 4s - loss: 0.4300 - accuracy: 0.8050 - val_loss: 0.4935 - val_accuracy: 0.7600 - 4s/epoch - 40ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.45923
# 100/100 - 4s - loss: 0.4303 - accuracy: 0.7950 - val_loss: 0.5489 - val_accuracy: 0.7780 - 4s/epoch - 41ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.45923
# 100/100 - 4s - loss: 0.4403 - accuracy: 0.7970 - val_loss: 0.4926 - val_accuracy: 0.7800 - 4s/epoch - 40ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 0.45923
# 100/100 - 4s - loss: 0.4304 - accuracy: 0.8050 - val_loss: 0.4779 - val_accuracy: 0.7720 - 4s/epoch - 42ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.45923
# 100/100 - 4s - loss: 0.4344 - accuracy: 0.8000 - val_loss: 0.4965 - val_accuracy: 0.7800 - 4s/epoch - 40ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.45923
# 100/100 - 4s - loss: 0.3842 - accuracy: 0.8250 - val_loss: 0.4670 - val_accuracy: 0.7960 - 4s/epoch - 41ms/step

# %%
# centering 만 했을 경우: 0.6920
# centering과 augmentation을 했을 경우: 0.7900
from tensorflow.keras.models import load_model
best_model = load_model(model_path)

# %% [markdown]
# - 테스트 이미지 분류

# %%
from google.colab import files

up = files.upload()
# Out:
#      <input type="file" id="files-88a62ec8-64ef-41e1-9967-c0373e231f56" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88a62ec8-64ef-41e1-9967-c0373e231f56">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpg to cat.jpg
# Saving dog.jpg to dog.jpg
# Saving dog1.jpg to dog1.jpg
# Saving dog2.jpg to dog2.jpg

# %%
for fname in up.keys():
    img = Image.open(fname)
    img = center_image(img)
    classes = best_model.predict(np.array(img).reshape(1,150,150,3))
    print(f"{classes[0,0]:.4f} {fname} is a {'dog' if classes[0,0] > 0.5 else 'cat'}")
# Out:
# 0.0000 cat.jpg is a cat
# 1.0000 dog.jpg is a dog
# 1.0000 dog1.jpg is a dog
# 0.0000 dog2.jpg is a cat

# %% [markdown]
# - 학습과정 시각화

# %%
import numpy as np
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
